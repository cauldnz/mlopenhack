# %% [markdown]
# Minimum imports to support running the project.
# - We use the preview Custom Vision Python API referenced [here](https://docs.microsoft.com/en-us/azure/cognitive-services/custom-vision-service/python-tutorial)
# - `yaml` for Config (see below for why we like this)
# - `os` for getting at the filesystem
# - `Augmentor` is a nice tidy image augmentation library for Python. Details [here](https://github.com/mdbloice/Augmentor).

# %%
import yaml
import os
from azure.cognitiveservices.vision.customvision.training import training_api
from azure.cognitiveservices.vision.customvision.training.models import ImageUrlCreateEntry
import Augmentor
import time
from azure.cognitiveservices.vision.customvision.prediction import prediction_endpoint
from azure.cognitiveservices.vision.customvision.prediction.prediction_endpoint import models

# %% [markdown]
# We externalize our secrets such that we can `.gitignore` the `config.yaml` file. This allows us to avoid checking secrets into version control because doing so is clearly the devil's work. We like YAML mainly because we dislike JSON (also the devil's work).

# %%
with open("config.yaml", 'r') as yamlfile:
    cfg = yaml.load(yamlfile)

credentials = cfg['credentials']

# %% [markdown]
# We force the project to use the `retail` domain. We need to reference domains by Id and so easiest to call `trainer.get_domains()` to fetch the Id values as they are not shown in the Custom Vision UI. To create a new project simply set the `project_id` to `""`.

# %%
project_id = "1dbbe791-46e4-4730-9214-9a601a4c5fa4" #Change this line to recreate the project.
training_key = credentials['training_key']
prediction_key = credentials['prediction_key']

trainer = training_api.TrainingApi(training_key)

if(len(project_id) > 0):
    # Create a new project
    print ("Creating project...")
    project = trainer.create_project("PuffyVsShell")
else:
    #Load existing project
    trainer.get_project(project_id)
# Out:
# Creating project...

# %%
# Make two tags in the new project
puffy_tag = trainer.create_tag(project.id, "Puffy")
shell_tag = trainer.create_tag(project.id, "Shell")

# %%
puffy_dir = "../gear_images/insulated_jackets"
for image in os.listdir(os.fsencode(puffy_dir)):
    with open(puffy_dir + "/" + os.fsdecode(image), mode="rb") as img_data:
        print('Uploading: {}'.format(image))
        trainer.create_images_from_data(project.id, img_data.read(), [ puffy_tag.id ])
print('Done')

# %%
shell_dir = "../gear_images/hardshell_jackets"
for image in os.listdir(os.fsencode(shell_dir)):
    with open(shell_dir + "/" + os.fsdecode(image), mode="rb") as img_data:
        print('Uploading: {}'.format(image))
        trainer.create_images_from_data(project.id, img_data.read(), [ shell_tag.id ])
print('Done')
# Out:
# Uploading: b'10269657x1110671_zm.jpeg'
# Uploading: b'10269570x1037095_zm.jpeg'
# Uploading: b'10331929x1050984_zm.jpeg'
# Uploading: b'10296834x1118322_zm.jpeg'
# Uploading: b'10237214x1012905_zm.jpeg'
# Uploading: b'111417.jpeg'
# Uploading: b'10116634x1038116_zm.jpeg'
# Uploading: b'10313298x1037114_zm.jpeg'
# Uploading: b'10333985x1011887_zm.jpeg'
# Uploading: b'118016.jpeg'
# Uploading: b'10333985x1013457_zm.jpeg'
# Uploading: b'10331926x1084490_zm.jpeg'
# Uploading: b'10320632x1012379_zm.jpeg'
# Uploading: b'10300494x1012905_zm.jpeg'
# Uploading: b'10374825x1010913_zm.jpeg'
# Uploading: b'10332294x1038816_zm.jpeg'
# Uploading: b'10302867x1150402_zm.jpeg'
# Uploading: b'117497.jpeg'
# Uploading: b'10345238x1151063_zm.jpeg'
# Uploading: b'10214105x1012870_zm.jpeg'
# Uploading: b'10342599x1014140_zm.jpeg'
# Uploading: b'10329963x1110671_zm.jpeg'
# Uploading: b'10349576x1068136_zm.jpeg'
# Uploading: b'10329549x1012798_zm.jpeg'
# Uploading: b'10207377x1012905_zm.jpeg'
# Uploading: b'10300351x1012905_zm.jpeg'
# Uploading: b'10254722x1114321_zm.jpeg'
# Uploading: b'10350143x1158212_zm.jpeg'
# Uploading: b'10313471x1006424_zm.jpeg'
# Uploading: b'10313318x1012905_zm.jpeg'
# Uploading: b'10220099x1016367_zm.jpeg'
# Uploading: b'894916.jpeg'
# Uploading: b'10330053x1079057_zm.jpeg'
# Uploading: b'10330387x1094207_zm.jpeg'
# Uploading: b'10330053x1011645_zm.jpeg'
# Uploading: b'10331819x1011957_zm.jpeg'
# Uploading: b'10332548x1130184_zm.jpeg'
# Uploading: b'10207377x1012295_zm.jpeg'
# Uploading: b'10185325x1113773_zm.jpeg'
# Uploading: b'10318268x1012905_zm.jpeg'
# Uploading: b'10237598x1012511_zm.jpeg'
# Uploading: b'10345306x1057989_zm.jpeg'
# Uploading: b'112126.jpeg'
# Uploading: b'10342598x1149124_zm.jpeg'
# Uploading: b'10329538x1081067_zm.jpeg'
# Uploading: b'10313191x1128654_zm.jpeg'
# Uploading: b'10349749x1046309_zm.jpeg'
# Uploading: b'10346605x1151920_zm.jpeg'
# Uploading: b'10324178x1136649_zm.jpeg'
# Uploading: b'10342599x1149060_zm.jpeg'
# Uploading: b'111876.jpeg'
# Uploading: b'10313191x1121354_zm.jpeg'
# Uploading: b'10329536x1128779_zm.jpeg'
# Uploading: b'10337690x1013055_zm.jpeg'
# Uploading: b'10281232x1012905_zm.jpeg'
# Uploading: b'10333985x1012905_zm.jpeg'
# Uploading: b'10345306x1012905_zm.jpeg'
# Uploading: b'10217842x1095790_zm.jpeg'
# Uploading: b'10313301x1118348_zm.jpeg'
# Uploading: b'10349576x1047360_zm.jpeg'
# Uploading: b'10251194x1108041_zm.jpeg'
# Uploading: b'10296834x1118325_zm.jpeg'
# Uploading: b'10280785x1040165_zm.jpeg'
# Uploading: b'10350143x1034282_zm.jpeg'
# Uploading: b'10185324x1011341_zm.jpeg'
# Uploading: b'887388.jpeg'
# Uploading: b'10313470x1128739_zm.jpeg'
# Uploading: b'10237214x1141696_zm.jpeg'
# Uploading: b'10349728x1047360_zm.jpeg'
# Uploading: b'10237598x1039510_zm.jpeg'
# Uploading: b'10317470x1131879_zm.jpeg'
# Uploading: b'10281309x1012905_zm.jpeg'
# Uploading: b'10312717x1044494_zm.jpeg'
# Uploading: b'10330031x1011144_zm.jpeg'
# Uploading: b'110026.jpeg'
# Uploading: b'10237214x1037243_zm.jpeg'
# Uploading: b'10330310x1037423_zm.jpeg'
# Uploading: b'10300495x1149691_zm.jpeg'
# Uploading: b'10318268x1151910_zm.jpeg'
# Uploading: b'10343683x1076923_zm.jpeg'
# Uploading: b'10245195x1077158_zm.jpeg'
# Uploading: b'10245196x1012905_zm.jpeg'
# Uploading: b'10331929x1150402_zm.jpeg'
# Uploading: b'10269634x1012905_zm.jpeg'
# Uploading: b'10269570x1012905_zm.jpeg'
# Uploading: b'10269657x1037095_zm.jpeg'
# Uploading: b'10313471x1120152_zm.jpeg'
# Uploading: b'10332246x1051050_zm.jpeg'
# Uploading: b'10343772x1012905_zm.jpeg'
# Uploading: b'10329964x1012905_zm.jpeg'
# Uploading: b'10330048x1011645_zm.jpeg'
# Uploading: b'10281756x1149691_zm.jpeg'
# Uploading: b'10207377x1130332_zm.jpeg'
# Uploading: b'10281309x1011177_zm.jpeg'
# Uploading: b'10313319x1128738_zm.jpeg'
# Uploading: b'10281830x1149691_zm.jpeg'
# Uploading: b'10281830x1012905_zm.jpeg'
# Uploading: b'10330465x1038337_zm.jpeg'
# Uploading: b'10300517x1037423_zm.jpeg'
# Uploading: b'10269634x1140754_zm.jpeg'
# Uploading: b'10300494x1108394_zm.jpeg'
# Uploading: b'118014.jpeg'
# Uploading: b'10342598x1015986_zm.jpeg'
# Uploading: b'10291507x1070726_zm.jpeg'
# Uploading: b'10318268x1039132_zm.jpeg'
# Uploading: b'10313471x1050117_zm.jpeg'
# Uploading: b'10185325x1011341_zm.jpeg'
# Uploading: b'10333985x1116117_zm.jpeg'
# Uploading: b'10184184x1140528_zm.jpeg'
# Uploading: b'10313470x1128738_zm.jpeg'
# Uploading: b'10207449x1013997_zm.jpeg'
# Uploading: b'863364.jpeg'
# Uploading: b'10281309x1140544_zm.jpeg'
# Uploading: b'10313302x1030283_zm.jpeg'
# Uploading: b'10313319x1035919_zm.jpeg'
# Uploading: b'10302305x1110654_zm.jpeg'
# Uploading: b'10337690x1023871_zm.jpeg'
# Uploading: b'10329538x1128738_zm.jpeg'
# Uploading: b'10226541x1036954_zm.jpeg'
# Uploading: b'10300495x1149856_zm.jpeg'
# Uploading: b'10354021x1084046_zm.jpeg'
# Uploading: b'10359422x1112774_zm.jpeg'
# Uploading: b'10317470x1131895_zm.jpeg'
# Uploading: b'10346605x1039107_zm.jpeg'
# Uploading: b'10330579x1012905_zm.jpeg'
# Uploading: b'10313302x1120209_zm.jpeg'
# Uploading: b'10302530x1122004_zm.jpeg'
# Uploading: b'10281756x1108328_zm.jpeg'
# Uploading: b'866781.jpeg'
# Uploading: b'10214105x1048213_zm.jpeg'
# Uploading: b'10331819x1037367_zm.jpeg'
# Uploading: b'10245196x1010868_zm.jpeg'
# Uploading: b'10331819x1012905_zm.jpeg'
# Uploading: b'10300495x1140836_zm.jpeg'
# Uploading: b'10300522x1076923_zm.jpeg'
# Uploading: b'10349749x1072641_zm.jpeg'
# Uploading: b'10217842x1075992_zm.jpeg'
# Uploading: b'10330309x1067347_zm.jpeg'
# Uploading: b'10220099x1043346_zm.jpeg'
# Uploading: b'108785.jpeg'
# Uploading: b'10345306x1118258_zm.jpeg'
# Uploading: b'10332548x1162504_zm.jpeg'
# Uploading: b'10220015x1128779_zm.jpeg'
# Uploading: b'10337690x1013583_zm.jpeg'
# Uploading: b'10332548x1051050_zm.jpeg'
# Uploading: b'10329964x1038429_zm.jpeg'
# Uploading: b'10207449x1050283_zm.jpeg'
# Uploading: b'10349909x1154301_zm.jpeg'
# Uploading: b'10330031x1063631_zm.jpeg'
# Uploading: b'10302867x1150787_zm.jpeg'
# Uploading: b'10334292x1068072_zm.jpeg'
# Uploading: b'10280785x1141723_zm.jpeg'
# Uploading: b'10116634x1072858_zm.jpeg'
# Uploading: b'10331926x1050984_zm.jpeg'
# Uploading: b'106260.jpeg'
# Uploading: b'10220010x1100878_zm.jpeg'
# Uploading: b'895322.jpeg'
# Uploading: b'10300494x1094207_zm.jpeg'
# Uploading: b'10317470x1131870_zm.jpeg'
# Uploading: b'10281158x1128790_zm.jpeg'
# Uploading: b'10296834x1012905_zm.jpeg'
# Uploading: b'10350132x1154394_zm.jpeg'
# Uploading: b'10300522x1149778_zm.jpeg'
# Uploading: b'10281310x1149113_zm.jpeg'
# Uploading: b'10337690x1012905_zm.jpeg'
# Uploading: b'10337690x1043102_zm.jpeg'
# Uploading: b'10350139x1155202_zm.jpeg'
# Uploading: b'10320632x1060335_zm.jpeg'
# Uploading: b'10207449x1012905_zm.jpeg'
# Uploading: b'10220010x1043346_zm.jpeg'
# Uploading: b'10281158x1093375_zm.jpeg'
# Uploading: b'10302867x1050984_zm.jpeg'
# Uploading: b'10281830x1149776_zm.jpeg'
# Uploading: b'880722.jpeg'
# Uploading: b'10332246x1131933_zm.jpeg'
# Uploading: b'10281309x1149086_zm.jpeg'
# Uploading: b'10220015x1012959_zm.jpeg'
# Uploading: b'10334353x1144016_zm.jpeg'
# Uploading: b'10184183x1012905_zm.jpeg'
# Uploading: b'10329549x1012905_zm.jpeg'
# Uploading: b'10332294x1072105_zm.jpeg'
# Uploading: b'10281232x1012425_zm.jpeg'
# Uploading: b'10281158x1012905_zm.jpeg'
# Uploading: b'10345238x1048963_zm.jpeg'
# Uploading: b'10374825x1169591_zm.jpeg'
# Uploading: b'10184183x1140544_zm.jpeg'
# Uploading: b'10237213x1107866_zm.jpeg'
# Uploading: b'10280785x1012400_zm.jpeg'
# Uploading: b'10281292x1128790_zm.jpeg'
# Uploading: b'10343771x1149691_zm.jpeg'
# Uploading: b'10343771x1037423_zm.jpeg'
# Uploading: b'10291507x1012905_zm.jpeg'
# Uploading: b'10359437x1014587_zm.jpeg'
# Uploading: b'10185325x1051972_zm.jpeg'
# Uploading: b'10301383x1037294_zm.jpeg'
# Uploading: b'10185325x1094992_zm.jpeg'
# Uploading: b'10349728x1068136_zm.jpeg'
# Uploading: b'10184925x1094142_zm.jpeg'
# Uploading: b'10313297x1012425_zm.jpeg'
# Uploading: b'10331928x1084490_zm.jpeg'
# Uploading: b'10184183x1012360_zm.jpeg'
# Uploading: b'110630.jpeg'
# Uploading: b'10237213x1120901_zm.jpeg'
# Uploading: b'10214106x1152818_zm.jpeg'
# Uploading: b'10330031x1110654_zm.jpeg'
# Uploading: b'10207377x1013311_zm.jpeg'
# Uploading: b'10291507x1038050_zm.jpeg'
# Uploading: b'10345306x1071771_zm.jpeg'
# Uploading: b'10207377x1037244_zm.jpeg'
# Uploading: b'10302305x1121354_zm.jpeg'
# Uploading: b'10330580x1140867_zm.jpeg'
# Uploading: b'10220015x1107525_zm.jpeg'
# Uploading: b'10330579x1076923_zm.jpeg'
# Uploading: b'10245195x1012905_zm.jpeg'
# Uploading: b'10184183x1140536_zm.jpeg'
# Uploading: b'10185324x1060609_zm.jpeg'
# Uploading: b'10313318x1011296_zm.jpeg'
# Uploading: b'893230.jpeg'
# Uploading: b'10300494x1128450_zm.jpeg'
# Uploading: b'10313297x1012905_zm.jpeg'
# Uploading: b'10237625x1068072_zm.jpeg'
# Uploading: b'10184925x1012371_zm.jpeg'
# Uploading: b'10300522x1044494_zm.jpeg'
# Uploading: b'10357292x1011831_zm.jpeg'
# Uploading: b'10220010x1149099_zm.jpeg'
# Uploading: b'10329537x1120209_zm.jpeg'
# Uploading: b'10343771x1012905_zm.jpeg'
# Uploading: b'884542.jpeg'
# Uploading: b'10349728x1011578_zm.jpeg'
# Uploading: b'10334292x1013997_zm.jpeg'
# Uploading: b'10313318x1063463_zm.jpeg'
# Uploading: b'101634.jpeg'
# Uploading: b'117218.jpeg'
# Uploading: b'10350138x1155202_zm.jpeg'
# Uploading: b'110709.jpeg'
# Uploading: b'10374826x1169591_zm.jpeg'
# Uploading: b'10237214x1107866_zm.jpeg'
# Uploading: b'10330031x1149168_zm.jpeg'
# Uploading: b'10342599x1128689_zm.jpeg'
# Uploading: b'10301383x1037298_zm.jpeg'
# Uploading: b'10254722x1012905_zm.jpeg'
# Uploading: b'112030.jpeg'
# Uploading: b'10350132x1086340_zm.jpeg'
# Uploading: b'10269657x1110654_zm.jpeg'
# Uploading: b'10330580x1012905_zm.jpeg'
# Uploading: b'10313301x1011296_zm.jpeg'
# Uploading: b'10349576x1012905_zm.jpeg'
# Uploading: b'10313302x1012798_zm.jpeg'
# Uploading: b'10220010x1012905_zm.jpeg'
# Uploading: b'10359422x1006424_zm.jpeg'
# Uploading: b'10349909x1012905_zm.jpeg'
# Uploading: b'859978.jpeg'
# Uploading: b'10317470x1152153_zm.jpeg'
# Uploading: b'10185324x1016653_zm.jpeg'
# Uploading: b'10281158x1128706_zm.jpeg'
# Uploading: b'10245195x1152818_zm.jpeg'
# Uploading: b'10317665x1012245_zm.jpeg'
# Uploading: b'10237625x1013303_zm.jpeg'
# Uploading: b'10302530x1058060_zm.jpeg'
# Uploading: b'10330310x1090156_zm.jpeg'
# Uploading: b'10313301x1012905_zm.jpeg'
# Uploading: b'10300351x1149781_zm.jpeg'
# Uploading: b'10313471x1012905_zm.jpeg'
# Uploading: b'10185325x1011131_zm.jpeg'
# Uploading: b'10245196x1152818_zm.jpeg'
# Uploading: b'10269657x1012905_zm.jpeg'
# Uploading: b'10349749x1154847_zm.jpeg'
# Uploading: b'10329963x1012905_zm.jpeg'
# Uploading: b'10329963x1037118_zm.jpeg'
# Uploading: b'10330310x1140867_zm.jpeg'
# Uploading: b'10354021x1104546_zm.jpeg'
# Uploading: b'10330387x1128450_zm.jpeg'
# Uploading: b'10320632x1012905_zm.jpeg'
# Uploading: b'10280745x1044757_zm.jpeg'
# Uploading: b'10329537x1035919_zm.jpeg'
# Uploading: b'10331929x1125962_zm.jpeg'
# Uploading: b'10220099x1012905_zm.jpeg'
# Uploading: b'10342598x1012905_zm.jpeg'
# Uploading: b'10291507x1039132_zm.jpeg'
# Uploading: b'10331819x1011163_zm.jpeg'
# Uploading: b'10300517x1108394_zm.jpeg'
# Uploading: b'10313470x1012905_zm.jpeg'
# Uploading: b'10184925x1107866_zm.jpeg'
# Uploading: b'10333985x1040165_zm.jpeg'
# Uploading: b'10300494x1149691_zm.jpeg'
# Uploading: b'10343772x1020558_zm.jpeg'
# Uploading: b'10343771x1067347_zm.jpeg'
# Uploading: b'10214106x1012234_zm.jpeg'
# Uploading: b'10252945x1012905_zm.jpeg'
# Uploading: b'120635.jpeg'
# Uploading: b'10302530x1147413_zm.jpeg'
# Uploading: b'10332124x1121963_zm.jpeg'
# Uploading: b'10252945x1076672_zm.jpeg'
# Uploading: b'10349909x1058035_zm.jpeg'
# Uploading: b'10330579x1140836_zm.jpeg'
# Uploading: b'10281233x1128689_zm.jpeg'
# Uploading: b'10330310x1012905_zm.jpeg'
# Uploading: b'10291507x1042015_zm.jpeg'
# Uploading: b'10345237x1036949_zm.jpeg'
# Uploading: b'10298220x1125016_zm.jpeg'
# Uploading: b'10350143x1012905_zm.jpeg'
# Uploading: b'10300351x1108394_zm.jpeg'
# Uploading: b'10300495x1012905_zm.jpeg'
# Uploading: b'111875.jpeg'
# Uploading: b'892141.jpeg'
# Uploading: b'10305872x1013634_zm.jpeg'
# Uploading: b'10374826x1011484_zm.jpeg'
# Uploading: b'10312717x1012905_zm.jpeg'
# Uploading: b'10331929x1150915_zm.jpeg'
# Uploading: b'10329549x1140544_zm.jpeg'
# Uploading: b'10302530x1050984_zm.jpeg'
# Uploading: b'10304249x1012905_zm.jpeg'
# Uploading: b'10269657x1140767_zm.jpeg'
# Uploading: b'10300351x1076923_zm.jpeg'
# Uploading: b'10281311x1012512_zm.jpeg'
# Uploading: b'10313298x1120209_zm.jpeg'
# Uploading: b'10184184x1120173_zm.jpeg'
# Uploading: b'10280744x1151124_zm.jpeg'
# Uploading: b'894338.jpeg'
# Uploading: b'10302867x1087139_zm.jpeg'
# Uploading: b'10330053x1011209_zm.jpeg'
# Uploading: b'10329549x1068533_zm.jpeg'
# Uploading: b'10281311x1027657_zm.jpeg'
# Uploading: b'10349909x1063978_zm.jpeg'
# Uploading: b'10280745x1038140_zm.jpeg'
# Uploading: b'10329964x1020626_zm.jpeg'
# Uploading: b'10334353x1012905_zm.jpeg'
# Uploading: b'120634.jpeg'
# Uploading: b'10313191x1012905_zm.jpeg'
# Uploading: b'10300351x1128450_zm.jpeg'
# Uploading: b'896903.jpeg'
# Uploading: b'10304249x1016191_zm.jpeg'
# Uploading: b'10354021x1011059_zm.jpeg'
# Uploading: b'880723.jpeg'
# Uploading: b'10300522x1108394_zm.jpeg'
# Uploading: b'10343998x1012905_zm.jpeg'
# Uploading: b'880724.jpeg'
# Uploading: b'10312590x1012905_zm.jpeg'
# Uploading: b'121398.jpeg'
# Uploading: b'10350132x1012905_zm.jpeg'
# Uploading: b'10296834x1144178_zm.jpeg'
# Uploading: b'10329536x1140551_zm.jpeg'
# Uploading: b'112127.jpeg'
# Uploading: b'10343998x1043087_zm.jpeg'
# Uploading: b'10281281x1149124_zm.jpeg'
# Uploading: b'10214105x1013039_zm.jpeg'
# Uploading: b'10300517x1149856_zm.jpeg'
# Uploading: b'10281756x1090156_zm.jpeg'
# Uploading: b'762351.jpeg'
# Uploading: b'10349728x1043201_zm.jpeg'
# Uploading: b'10331929x1130244_zm.jpeg'
# Uploading: b'10345307x1141723_zm.jpeg'
# Uploading: b'10329964x1106755_zm.jpeg'
# Uploading: b'10342599x1069414_zm.jpeg'
# Uploading: b'10281292x1128690_zm.jpeg'
# Uploading: b'10280745x1151214_zm.jpeg'
# Uploading: b'10332294x1058188_zm.jpeg'
# Uploading: b'112128.jpeg'
# Uploading: b'10245195x1079256_zm.jpeg'
# Uploading: b'10332246x1046388_zm.jpeg'
# Uploading: b'10329536x1012425_zm.jpeg'
# Uploading: b'10313301x1012798_zm.jpeg'
# Uploading: b'10252945x1076923_zm.jpeg'
# Uploading: b'10302867x1058060_zm.jpeg'
# Uploading: b'10343683x1067347_zm.jpeg'
# Uploading: b'10334353x1123004_zm.jpeg'
# Uploading: b'10207449x1078442_zm.jpeg'
# Uploading: b'10269570x1013253_zm.jpeg'
# Uploading: b'10312590x1044494_zm.jpeg'
# Uploading: b'895441.jpeg'
# Uploading: b'10332548x1072105_zm.jpeg'
# Uploading: b'10334292x1130321_zm.jpeg'
# Uploading: b'10237213x1151124_zm.jpeg'
# Uploading: b'10251194x1140551_zm.jpeg'
# Uploading: b'10330031x1012905_zm.jpeg'
# Uploading: b'10349728x1012905_zm.jpeg'
# Uploading: b'10281233x1045400_zm.jpeg'
# Uploading: b'10305872x1012905_zm.jpeg'
# Uploading: b'10320632x1013649_zm.jpeg'
# Uploading: b'10345307x1083191_zm.jpeg'
# Uploading: b'10318268x1013059_zm.jpeg'
# Uploading: b'10329963x1149142_zm.jpeg'
# Uploading: b'10330310x1149856_zm.jpeg'
# Uploading: b'10301383x1012905_zm.jpeg'
# Uploading: b'10214105x1012905_zm.jpeg'
# Uploading: b'10313319x1149069_zm.jpeg'
# Uploading: b'10345237x1048963_zm.jpeg'
# Uploading: b'10281233x1128790_zm.jpeg'
# Uploading: b'10313301x1140544_zm.jpeg'
# Uploading: b'10300517x1149780_zm.jpeg'
# Uploading: b'10331926x1121979_zm.jpeg'
# Uploading: b'10184183x1068533_zm.jpeg'
# Uploading: b'10300517x1012905_zm.jpeg'
# Uploading: b'10349749x1012905_zm.jpeg'
# Uploading: b'10329964x1140756_zm.jpeg'
# Uploading: b'10214106x1012905_zm.jpeg'
# Uploading: b'10185324x1130335_zm.jpeg'
# Uploading: b'10300495x1108394_zm.jpeg'
# Uploading: b'10343772x1149670_zm.jpeg'
# Uploading: b'10313319x1128689_zm.jpeg'
# Uploading: b'10331926x1038605_zm.jpeg'
# Uploading: b'10269634x1063631_zm.jpeg'
# Uploading: b'10312590x1149778_zm.jpeg'
# Uploading: b'10330387x1064322_zm.jpeg'
# Uploading: b'10237598x1012870_zm.jpeg'
# Uploading: b'10313297x1149124_zm.jpeg'
# Uploading: b'10331928x1050984_zm.jpeg'
# Uploading: b'10300522x1012905_zm.jpeg'
# Uploading: b'10349749x1103823_zm.jpeg'
# Uploading: b'10332548x1106708_zm.jpeg'
# Uploading: b'10332124x1131592_zm.jpeg'
# Uploading: b'10185324x1013303_zm.jpeg'
# Uploading: b'10184184x1035919_zm.jpeg'
# Uploading: b'124431.jpeg'
# Uploading: b'10302530x1039264_zm.jpeg'
# Uploading: b'10317665x1012905_zm.jpeg'
# Uploading: b'10313318x1140544_zm.jpeg'
# Uploading: b'10345307x1012400_zm.jpeg'
# Uploading: b'10313302x1128790_zm.jpeg'
# Uploading: b'10281756x1149856_zm.jpeg'
# Uploading: b'10329963x1140770_zm.jpeg'
# Uploading: b'10207449x1011204_zm.jpeg'
# Uploading: b'845409.jpeg'
# Uploading: b'10349576x1110709_zm.jpeg'
# Uploading: b'10217842x1043293_zm.jpeg'
# Uploading: b'102018.jpeg'
# Uploading: b'10281281x1012905_zm.jpeg'
# Uploading: b'895794.jpeg'
# Uploading: b'121966.jpeg'
# Uploading: b'10329538x1128689_zm.jpeg'
# Uploading: b'10214106x1037134_zm.jpeg'
# Uploading: b'10331928x1084272_zm.jpeg'
# Uploading: b'10226541x1012905_zm.jpeg'
# Uploading: b'10214106x1010868_zm.jpeg'
# Uploading: b'10331928x1043700_zm.jpeg'
# Uploading: b'10329549x1013684_zm.jpeg'
# Uploading: b'10330309x1037423_zm.jpeg'
# Uploading: b'10217842x1036924_zm.jpeg'
# Uploading: b'10220010x1140544_zm.jpeg'
# Uploading: b'10281233x1149113_zm.jpeg'
# Uploading: b'10349576x1152327_zm.jpeg'
# Uploading: b'10251194x1012425_zm.jpeg'
# Uploading: b'10330309x1149711_zm.jpeg'
# Uploading: b'10184184x1061637_zm.jpeg'
# Uploading: b'10343683x1012905_zm.jpeg'
# Uploading: b'10237213x1011463_zm.jpeg'
# Uploading: b'880692.jpeg'
# Uploading: b'10237213x1012905_zm.jpeg'
# Uploading: b'894317.jpeg'
# Uploading: b'10331928x1072105_zm.jpeg'
# Uploading: b'10269570x1140758_zm.jpeg'
# Uploading: b'10330309x1012905_zm.jpeg'
# Uploading: b'10116634x1068361_zm.jpeg'
# Uploading: b'10184184x1036924_zm.jpeg'
# Uploading: b'119214.jpeg'
# Uploading: b'10281311x1012905_zm.jpeg'
# Uploading: b'10184925x1012905_zm.jpeg'
# Uploading: b'10359437x1046309_zm.jpeg'
# Uploading: b'104837.jpeg'

# %%
print(project.id)
# Out:
# 1dbbe791-46e4-4730-9214-9a601a4c5fa4

# %%
print ("Training...")
iteration = trainer.train_project(project.id)
while (iteration.status == "Training"):
    iteration = trainer.get_iteration(project.id, iteration.id)
    print ("Training status: " + iteration.status)
    time.sleep(1)

# The iteration is now trained. Make it the default project endpoint
trainer.update_iteration(project.id, iteration.id, is_default=True)
print ("Done!")

# %% [markdown]
# We now test with two images that were not used in training.
#
# Puffy Jacket
# <img src="http://assets.supremenewyork.com/142654/zo/C9rZR7_iq1g1.jpg" alt="Drawing" width="200" height="200"/>
#
# Hardshell Jacket
# <img src="https://pro.arcteryx.com/assets/images/products/mountain-guide-jacket@2x.png" alt="Drawing" width="200" height="200"/>

# %%
# Now there is a trained endpoint that can be used to make a prediction

predictor = prediction_endpoint.PredictionEndpoint(prediction_key)

test_img_url = "http://assets.supremenewyork.com/142654/zo/C9rZR7_iq1g1.jpg"
results = predictor.predict_image_url(project.id, iteration.id, url=test_img_url)
  
# Display the results.
for prediction in results.predictions:
    print ("Prediction for {}".format(test_img_url))
    print ("\t" + prediction.tag + ": {0:.2f}%".format(prediction.probability * 100))
    
    
test_img_url = "https://pro.arcteryx.com/assets/images/products/mountain-guide-jacket@2x.png"
results = predictor.predict_image_url(project.id, iteration.id, url=test_img_url)
  
# Display the results.
for prediction in results.predictions:
    print ("Prediction for {}".format(test_img_url))
    print ("\t" + prediction.tag + ": {0:.2f}%".format(prediction.probability * 100))
# Out:
# Prediction for http://assets.supremenewyork.com/142654/zo/C9rZR7_iq1g1.jpg
# 	Puffy: 92.29%
# Prediction for http://assets.supremenewyork.com/142654/zo/C9rZR7_iq1g1.jpg
# 	Shell: 5.20%
# Prediction for https://pro.arcteryx.com/assets/images/products/mountain-guide-jacket@2x.png
# 	Shell: 100.00%
# Prediction for https://pro.arcteryx.com/assets/images/products/mountain-guide-jacket@2x.png
# 	Puffy: 0.01%
